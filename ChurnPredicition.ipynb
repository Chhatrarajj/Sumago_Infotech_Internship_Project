# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib import style
style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

# %%
df  =pd.read_csv('Churn_Modelling.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.sample(10)
# Out:
#       RowNumber  CustomerId       Surname  CreditScore Geography  Gender  Age  \
# 4067       4068    15767391  Otutodilinna          565   Germany  Female   32
# 1349       1350    15778135          T'ao          575     Spain    Male   43
# 4151       4152    15569098      Winifred          627    France    Male   44
# 1433       1434    15585282     Trevisano          755    France    Male   62
# 4498       4499    15777759       Boucaut          570    France    Male   30
# 4431       4432    15783629    Degtyaryov          616   Germany  Female   42
# 9072       9073    15777315          Hill          529    France    Male   43
# 8664       8665    15666332     Donaldson          690     Spain  Female   48
# 4776       4777    15677123     Aksyonova          767     Spain    Male   37
# 2339       2340    15647975          Vida          651   Germany    Male   26
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
x = df.drop(['RowNumber','CustomerId','Exited'],axis=1).values
y = df['Exited'].values

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[['Age','EstimatedSalary','Balance','CreditScore','Tenure','NumOfProducts']]=scaler.fit_transform(df[['Age','EstimatedSalary','Balance','CreditScore','Tenure','NumOfProducts']])
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  \
# 0             1    15634602   Hargrave    -0.326221    France  Female
# 1             2    15647311       Hill    -0.440036     Spain  Female
# 2             3    15619304       Onio    -1.536794    France  Female
# 3             4    15701354       Boni     0.501521    France  Female
# 4             5    15737888   Mitchell     2.063884     Spain  Female
# ...         ...         ...        ...          ...       ...     ...
# 9995       9996    15606229   Obijiaku     1.246488    France    Male
# 9996       9997    15569892  Johnstone    -1.391939    France    Male
# 9997       9998    15584532        Liu     0.604988    France  Female
# 9998       9999    15682355  Sabbatini     1.256835   Germany    Male
# 9999      10000    15628319     Walker     1.463771    France  Female
#
#            Age    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df['Geography'] = encoder.fit_transform(df['Geography'])
df['Surname'] = encoder.fit_transform(df['Surname'])
df['Gender'] = encoder.fit_transform(df['Gender'])

# %%
df
# Out:
#       RowNumber  CustomerId  Surname  CreditScore  Geography  Gender  \
# 0             1    15634602     1115    -0.326221          0       0
# 1             2    15647311     1177    -0.440036          2       0
# 2             3    15619304     2040    -1.536794          0       0
# 3             4    15701354      289     0.501521          0       0
# 4             5    15737888     1822     2.063884          2       0
# ...         ...         ...      ...          ...        ...     ...
# 9995       9996    15606229     1999     1.246488          0       1
# 9996       9997    15569892     1336    -1.391939          0       1
# 9997       9998    15584532     1570     0.604988          0       0
# 9998       9999    15682355     2345     1.256835          1       1
# 9999      10000    15628319     2751     1.463771          0       0
#
#            Age    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
x = df.drop(['RowNumber','CustomerId','Exited','Surname'],axis=1).values
y = df['Exited'].values

# %%
x
# Out:
# array([[-0.32622142,  0.        ,  0.        , ...,  1.        ,
#          1.        ,  0.02188649],
#        [-0.44003595,  2.        ,  0.        , ...,  0.        ,
#          1.        ,  0.21653375],
#        [-1.53679418,  0.        ,  0.        , ...,  1.        ,
#          0.        ,  0.2406869 ],
#        ...,
#        [ 0.60498839,  0.        ,  0.        , ...,  0.        ,
#          1.        , -1.00864308],
#        [ 1.25683526,  1.        ,  1.        , ...,  1.        ,
#          0.        , -0.12523071],
#        [ 1.46377078,  0.        ,  0.        , ...,  1.        ,
#          0.        , -1.07636976]])

# %%
y
# Out:
# array([1, 0, 1, ..., 1, 1, 0], dtype=int64)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_train,y_train)
# Out:
# 0.8105

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1,random_state=4)

# %%
#knn
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=13)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %%
knn.score(x_test,y_test)
# Out:
# 0.871

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.svm import SVC
model = SVC()

# %%
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
model.score(x_test,y_test)
# Out:
# 0.858
